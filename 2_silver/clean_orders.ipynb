# %% [markdown]
# ## Tratamento de bases

# %%
import pandas as pd 
import os

ABS_PATH = os.path.abspath('..')

BRONZE_PATH = os.path.join(ABS_PATH,'1_bronze')


a, *_ = os.listdir(BRONZE_PATH)

df = pd.read_csv(f'{BRONZE_PATH}/{a}')

df
