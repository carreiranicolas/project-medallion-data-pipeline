# %% [markdown]
# ## Silver – Orders
#
# ### 1. Leitura da camada Bronze
# ### 2. Inspeção inicial
# ### 3. Conversão de tipos
# ### 4. Regras de qualidade
# ### 5. Escrita da camada Silver

# %%
import pandas as pd 
from pathlib import Path


ABS_PATH = Path('.').resolve()

BRONZE_PATH = ABS_PATH.parent.parent.joinpath('data/1_bronze')

ARQUIVOS = [arquivo for arquivo in BRONZE_PATH.iterdir()]

df = pd.read_csv(ARQUIVOS[0])

df
